# %%
import requests
import pandas as pd 
import json
import time
# import relevant libraries
# Welcome to Group 2

# %% [markdown]
# # API part

# %% [markdown]
# ## members of API part

# %% [markdown]
# YUNPENG LU(2014873)

# %% [markdown]
# JIAOHAO SHANG(2087608)

# %% [markdown]
# XINAN LI(2090506)

# %% [markdown]
# ## State

# %%
location_url1 = "https://localcoviddata.com/covid19/v1/cases/jhu?state="
# first part of url
location_url2= "&daysInPast=7"
# second part of url
def location_generator(query="AL"):
    # default state = 'Alabama', whose state_code is 'AL'
    # We should note that the query should be the state_code of the state, rather than full name of the state
    query = query.replace(" ", "%20")
    # replace space with '%20'
    r = requests.get(location_url1 + query + location_url2)
    # equals to https://localcoviddata.com/covid19/v1/cases/jhu?state=AL&daysInPast=7, 
    # which will return the covid data in last 7 days of Alabama
    return r

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv'
df = pd.read_csv(url)
# df represents all the data of every name of state and county
df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 3   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
# 4   24   AO  AGO   24.0   NaN    NaN            NaN         Angola -11.20270
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2   1.659600      Algeria  43851043.0
# 3   1.521800      Andorra     77265.0
# 4  17.873900       Angola  32866268.0

# %%
df_state = df.iloc[968:1019,:]
# 968 to 1019 lines of this document represents the data of every state and its state_code
df_state
# Out:
#            UID iso2 iso3  code3     FIPS     Admin2        Province_State  \
# 968   84080001   US  USA  840.0  80001.0  Out of AL               Alabama
# 969   84080002   US  USA  840.0  80002.0  Out of AK                Alaska
# 970   84080004   US  USA  840.0  80004.0  Out of AZ               Arizona
# 971   84080005   US  USA  840.0  80005.0  Out of AR              Arkansas
# 972   84080006   US  USA  840.0  80006.0  Out of CA            California
# 973   84080008   US  USA  840.0  80008.0  Out of CO              Colorado
# 974   84080009   US  USA  840.0  80009.0  Out of CT           Connecticut
# 975   84080010   US  USA  840.0  80010.0  Out of DE              Delaware
# 976   84080011   US  USA  840.0  80011.0  Out of DC  District of Columbia
# 977   84080012   US  USA  840.0  80012.0  Out of FL               Florida
# 978   84080013   US  USA  840.0  80013.0  Out of GA               Georgia
# 979   84080015   US  USA  840.0  80015.0  Out of HI                Hawaii
# 980   84080016   US  USA  840.0  80016.0  Out of ID                 Idaho
# 981   84080017   US  USA  840.0  80017.0  Out of IL              Illinois
# 982   84080018   US  USA  840.0  80018.0  Out of IN               Indiana
# 983   84080019   US  USA  840.0  80019.0  Out of IA                  Iowa
# 984   84080020   US  USA  840.0  80020.0  Out of KS                Kansas
# 985   84080021   US  USA  840.0  80021.0  Out of KY              Kentucky
# 986   84080022   US  USA  840.0  80022.0  Out of LA             Louisiana
# 987   84080023   US  USA  840.0  80023.0  Out of ME                 Maine
# 988   84080024   US  USA  840.0  80024.0  Out of MD              Maryland
# 989   84080025   US  USA  840.0  80025.0  Out of MA         Massachusetts
# 990   84080026   US  USA  840.0  80026.0  Out of MI              Michigan
# 991   84080027   US  USA  840.0  80027.0  Out of MN             Minnesota
# 992   84080028   US  USA  840.0  80028.0  Out of MS           Mississippi
# 993   84080029   US  USA  840.0  80029.0  Out of MO              Missouri
# 994   84080030   US  USA  840.0  80030.0  Out of MT               Montana
# 995   84080031   US  USA  840.0  80031.0  Out of NE              Nebraska
# 996   84080032   US  USA  840.0  80032.0  Out of NV                Nevada
# 997   84080033   US  USA  840.0  80033.0  Out of NH         New Hampshire
# 998   84080034   US  USA  840.0  80034.0  Out of NJ            New Jersey
# 999   84080035   US  USA  840.0  80035.0  Out of NM            New Mexico
# 1000  84080036   US  USA  840.0  80036.0  Out of NY              New York
# 1001  84080037   US  USA  840.0  80037.0  Out of NC        North Carolina
# 1002  84080038   US  USA  840.0  80038.0  Out of ND          North Dakota
# 1003  84080039   US  USA  840.0  80039.0  Out of OH                  Ohio
# 1004  84080040   US  USA  840.0  80040.0  Out of OK              Oklahoma
# 1005  84080041   US  USA  840.0  80041.0  Out of OR                Oregon
# 1006  84080042   US  USA  840.0  80042.0  Out of PA          Pennsylvania
# 1007  84080044   US  USA  840.0  80044.0  Out of RI          Rhode Island
# 1008  84080045   US  USA  840.0  80045.0  Out of SC        South Carolina
# 1009  84080046   US  USA  840.0  80046.0  Out of SD          South Dakota
# 1010  84080047   US  USA  840.0  80047.0  Out of TN             Tennessee
# 1011  84080048   US  USA  840.0  80048.0  Out of TX                 Texas
# 1012  84080049   US  USA  840.0  80049.0  Out of UT                  Utah
# 1013  84080050   US  USA  840.0  80050.0  Out of VT               Vermont
# 1014  84080051   US  USA  840.0  80051.0  Out of VA              Virginia
# 1015  84080053   US  USA  840.0  80053.0  Out of WA            Washington
# 1016  84080054   US  USA  840.0  80054.0  Out of WV         West Virginia
# 1017  84080055   US  USA  840.0  80055.0  Out of WI             Wisconsin
# 1018  84080056   US  USA  840.0  80056.0  Out of WY               Wyoming
#
#      Country_Region  Lat  Long_                         Combined_Key  \
# 968              US  NaN    NaN               Out of AL, Alabama, US
# 969              US  NaN    NaN                Out of AK, Alaska, US
# 970              US  NaN    NaN               Out of AZ, Arizona, US
# 971              US  NaN    NaN              Out of AR, Arkansas, US
# 972              US  NaN    NaN            Out of CA, California, US
# 973              US  NaN    NaN              Out of CO, Colorado, US
# 974              US  NaN    NaN           Out of CT, Connecticut, US
# 975              US  NaN    NaN              Out of DE, Delaware, US
# 976              US  NaN    NaN  Out of DC, District of Columbia, US
# 977              US  NaN    NaN               Out of FL, Florida, US
# 978              US  NaN    NaN               Out of GA, Georgia, US
# 979              US  NaN    NaN                Out of HI, Hawaii, US
# 980              US  NaN    NaN                 Out of ID, Idaho, US
# 981              US  NaN    NaN              Out of IL, Illinois, US
# 982              US  NaN    NaN               Out of IN, Indiana, US
# 983              US  NaN    NaN                  Out of IA, Iowa, US
# 984              US  NaN    NaN                Out of KS, Kansas, US
# 985              US  NaN    NaN              Out of KY, Kentucky, US
# 986              US  NaN    NaN             Out of LA, Louisiana, US
# 987              US  NaN    NaN                 Out of ME, Maine, US
# 988              US  NaN    NaN              Out of MD, Maryland, US
# 989              US  NaN    NaN         Out of MA, Massachusetts, US
# 990              US  NaN    NaN              Out of MI, Michigan, US
# 991              US  NaN    NaN             Out of MN, Minnesota, US
# 992              US  NaN    NaN           Out of MS, Mississippi, US
# 993              US  NaN    NaN              Out of MO, Missouri, US
# 994              US  NaN    NaN               Out of MT, Montana, US
# 995              US  NaN    NaN              Out of NE, Nebraska, US
# 996              US  NaN    NaN                Out of NV, Nevada, US
# 997              US  NaN    NaN         Out of NH, New Hampshire, US
# 998              US  NaN    NaN            Out of NJ, New Jersey, US
# 999              US  NaN    NaN            Out of NM, New Mexico, US
# 1000             US  NaN    NaN              Out of NY, New York, US
# 1001             US  NaN    NaN        Out of NC, North Carolina, US
# 1002             US  NaN    NaN          Out of ND, North Dakota, US
# 1003             US  NaN    NaN                  Out of OH, Ohio, US
# 1004             US  NaN    NaN              Out of OK, Oklahoma, US
# 1005             US  NaN    NaN                Out of OR, Oregon, US
# 1006             US  NaN    NaN          Out of PA, Pennsylvania, US
# 1007             US  NaN    NaN          Out of RI, Rhode Island, US
# 1008             US  NaN    NaN        Out of SC, South Carolina, US
# 1009             US  NaN    NaN          Out of SD, South Dakota, US
# 1010             US  NaN    NaN             Out of TN, Tennessee, US
# 1011             US  NaN    NaN                 Out of TX, Texas, US
# 1012             US  NaN    NaN                  Out of UT, Utah, US
# 1013             US  NaN    NaN               Out of VT, Vermont, US
# 1014             US  NaN    NaN              Out of VA, Virginia, US
# 1015             US  NaN    NaN            Out of WA, Washington, US
# 1016             US  NaN    NaN         Out of WV, West Virginia, US
# 1017             US  NaN    NaN             Out of WI, Wisconsin, US
# 1018             US  NaN    NaN               Out of WY, Wyoming, US
#
#       Population
# 968          NaN
# 969          NaN
# 970          NaN
# 971          NaN
# 972          NaN
# 973          NaN
# 974          NaN
# 975          NaN
# 976          NaN
# 977          NaN
# 978          NaN
# 979          NaN
# 980          NaN
# 981          NaN
# 982          NaN
# 983          NaN
# 984          NaN
# 985          NaN
# 986          NaN
# 987          NaN
# 988          NaN
# 989          NaN
# 990          NaN
# 991          NaN
# 992          NaN
# 993          NaN
# 994          NaN
# 995          NaN
# 996          NaN
# 997          NaN
# 998          NaN
# 999          NaN
# 1000         NaN
# 1001         NaN
# 1002         NaN
# 1003         NaN
# 1004         NaN
# 1005         NaN
# 1006         NaN
# 1007         NaN
# 1008         NaN
# 1009         NaN
# 1010         NaN
# 1011         NaN
# 1012         NaN
# 1013         NaN
# 1014         NaN
# 1015         NaN
# 1016         NaN
# 1017         NaN
# 1018         NaN

# %%
def f(x):
    return x['Admin2'].split(' ')[2]
df_state['state_code'] = df_state.apply(lambda x:f(x),axis = 1)
# f(x) function is used to extract the useful part of Admin2, which represents the state_code of every state
# for example, 'AL' is the state_code of Alabama
# Out:
# <ipython-input-5-3f1ed0364cfb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_state['state_code'] = df_state.apply(lambda x:f(x),axis = 1)

# %%
df_state = df_state.reset_index(drop = True)
df_state
# we generate a new column named state_code, which is easier to find relevant data in the website
# Out:
#          UID iso2 iso3  code3     FIPS     Admin2        Province_State  \
# 0   84080001   US  USA  840.0  80001.0  Out of AL               Alabama
# 1   84080002   US  USA  840.0  80002.0  Out of AK                Alaska
# 2   84080004   US  USA  840.0  80004.0  Out of AZ               Arizona
# 3   84080005   US  USA  840.0  80005.0  Out of AR              Arkansas
# 4   84080006   US  USA  840.0  80006.0  Out of CA            California
# 5   84080008   US  USA  840.0  80008.0  Out of CO              Colorado
# 6   84080009   US  USA  840.0  80009.0  Out of CT           Connecticut
# 7   84080010   US  USA  840.0  80010.0  Out of DE              Delaware
# 8   84080011   US  USA  840.0  80011.0  Out of DC  District of Columbia
# 9   84080012   US  USA  840.0  80012.0  Out of FL               Florida
# 10  84080013   US  USA  840.0  80013.0  Out of GA               Georgia
# 11  84080015   US  USA  840.0  80015.0  Out of HI                Hawaii
# 12  84080016   US  USA  840.0  80016.0  Out of ID                 Idaho
# 13  84080017   US  USA  840.0  80017.0  Out of IL              Illinois
# 14  84080018   US  USA  840.0  80018.0  Out of IN               Indiana
# 15  84080019   US  USA  840.0  80019.0  Out of IA                  Iowa
# 16  84080020   US  USA  840.0  80020.0  Out of KS                Kansas
# 17  84080021   US  USA  840.0  80021.0  Out of KY              Kentucky
# 18  84080022   US  USA  840.0  80022.0  Out of LA             Louisiana
# 19  84080023   US  USA  840.0  80023.0  Out of ME                 Maine
# 20  84080024   US  USA  840.0  80024.0  Out of MD              Maryland
# 21  84080025   US  USA  840.0  80025.0  Out of MA         Massachusetts
# 22  84080026   US  USA  840.0  80026.0  Out of MI              Michigan
# 23  84080027   US  USA  840.0  80027.0  Out of MN             Minnesota
# 24  84080028   US  USA  840.0  80028.0  Out of MS           Mississippi
# 25  84080029   US  USA  840.0  80029.0  Out of MO              Missouri
# 26  84080030   US  USA  840.0  80030.0  Out of MT               Montana
# 27  84080031   US  USA  840.0  80031.0  Out of NE              Nebraska
# 28  84080032   US  USA  840.0  80032.0  Out of NV                Nevada
# 29  84080033   US  USA  840.0  80033.0  Out of NH         New Hampshire
# 30  84080034   US  USA  840.0  80034.0  Out of NJ            New Jersey
# 31  84080035   US  USA  840.0  80035.0  Out of NM            New Mexico
# 32  84080036   US  USA  840.0  80036.0  Out of NY              New York
# 33  84080037   US  USA  840.0  80037.0  Out of NC        North Carolina
# 34  84080038   US  USA  840.0  80038.0  Out of ND          North Dakota
# 35  84080039   US  USA  840.0  80039.0  Out of OH                  Ohio
# 36  84080040   US  USA  840.0  80040.0  Out of OK              Oklahoma
# 37  84080041   US  USA  840.0  80041.0  Out of OR                Oregon
# 38  84080042   US  USA  840.0  80042.0  Out of PA          Pennsylvania
# 39  84080044   US  USA  840.0  80044.0  Out of RI          Rhode Island
# 40  84080045   US  USA  840.0  80045.0  Out of SC        South Carolina
# 41  84080046   US  USA  840.0  80046.0  Out of SD          South Dakota
# 42  84080047   US  USA  840.0  80047.0  Out of TN             Tennessee
# 43  84080048   US  USA  840.0  80048.0  Out of TX                 Texas
# 44  84080049   US  USA  840.0  80049.0  Out of UT                  Utah
# 45  84080050   US  USA  840.0  80050.0  Out of VT               Vermont
# 46  84080051   US  USA  840.0  80051.0  Out of VA              Virginia
# 47  84080053   US  USA  840.0  80053.0  Out of WA            Washington
# 48  84080054   US  USA  840.0  80054.0  Out of WV         West Virginia
# 49  84080055   US  USA  840.0  80055.0  Out of WI             Wisconsin
# 50  84080056   US  USA  840.0  80056.0  Out of WY               Wyoming
#
#    Country_Region  Lat  Long_                         Combined_Key  \
# 0              US  NaN    NaN               Out of AL, Alabama, US
# 1              US  NaN    NaN                Out of AK, Alaska, US
# 2              US  NaN    NaN               Out of AZ, Arizona, US
# 3              US  NaN    NaN              Out of AR, Arkansas, US
# 4              US  NaN    NaN            Out of CA, California, US
# 5              US  NaN    NaN              Out of CO, Colorado, US
# 6              US  NaN    NaN           Out of CT, Connecticut, US
# 7              US  NaN    NaN              Out of DE, Delaware, US
# 8              US  NaN    NaN  Out of DC, District of Columbia, US
# 9              US  NaN    NaN               Out of FL, Florida, US
# 10             US  NaN    NaN               Out of GA, Georgia, US
# 11             US  NaN    NaN                Out of HI, Hawaii, US
# 12             US  NaN    NaN                 Out of ID, Idaho, US
# 13             US  NaN    NaN              Out of IL, Illinois, US
# 14             US  NaN    NaN               Out of IN, Indiana, US
# 15             US  NaN    NaN                  Out of IA, Iowa, US
# 16             US  NaN    NaN                Out of KS, Kansas, US
# 17             US  NaN    NaN              Out of KY, Kentucky, US
# 18             US  NaN    NaN             Out of LA, Louisiana, US
# 19             US  NaN    NaN                 Out of ME, Maine, US
# 20             US  NaN    NaN              Out of MD, Maryland, US
# 21             US  NaN    NaN         Out of MA, Massachusetts, US
# 22             US  NaN    NaN              Out of MI, Michigan, US
# 23             US  NaN    NaN             Out of MN, Minnesota, US
# 24             US  NaN    NaN           Out of MS, Mississippi, US
# 25             US  NaN    NaN              Out of MO, Missouri, US
# 26             US  NaN    NaN               Out of MT, Montana, US
# 27             US  NaN    NaN              Out of NE, Nebraska, US
# 28             US  NaN    NaN                Out of NV, Nevada, US
# 29             US  NaN    NaN         Out of NH, New Hampshire, US
# 30             US  NaN    NaN            Out of NJ, New Jersey, US
# 31             US  NaN    NaN            Out of NM, New Mexico, US
# 32             US  NaN    NaN              Out of NY, New York, US
# 33             US  NaN    NaN        Out of NC, North Carolina, US
# 34             US  NaN    NaN          Out of ND, North Dakota, US
# 35             US  NaN    NaN                  Out of OH, Ohio, US
# 36             US  NaN    NaN              Out of OK, Oklahoma, US
# 37             US  NaN    NaN                Out of OR, Oregon, US
# 38             US  NaN    NaN          Out of PA, Pennsylvania, US
# 39             US  NaN    NaN          Out of RI, Rhode Island, US
# 40             US  NaN    NaN        Out of SC, South Carolina, US
# 41             US  NaN    NaN          Out of SD, South Dakota, US
# 42             US  NaN    NaN             Out of TN, Tennessee, US
# 43             US  NaN    NaN                 Out of TX, Texas, US
# 44             US  NaN    NaN                  Out of UT, Utah, US
# 45             US  NaN    NaN               Out of VT, Vermont, US
# 46             US  NaN    NaN              Out of VA, Virginia, US
# 47             US  NaN    NaN            Out of WA, Washington, US
# 48             US  NaN    NaN         Out of WV, West Virginia, US
# 49             US  NaN    NaN             Out of WI, Wisconsin, US
# 50             US  NaN    NaN               Out of WY, Wyoming, US
#
#     Population state_code
# 0          NaN         AL
# 1          NaN         AK
# 2          NaN         AZ
# 3          NaN         AR
# 4          NaN         CA
# 5          NaN         CO
# 6          NaN         CT
# 7          NaN         DE
# 8          NaN         DC
# 9          NaN         FL
# 10         NaN         GA
# 11         NaN         HI
# 12         NaN         ID
# 13         NaN         IL
# 14         NaN         IN
# 15         NaN         IA
# 16         NaN         KS
# 17         NaN         KY
# 18         NaN         LA
# 19         NaN         ME
# 20         NaN         MD
# 21         NaN         MA
# 22         NaN         MI
# 23         NaN         MN
# 24         NaN         MS
# 25         NaN         MO
# 26         NaN         MT
# 27         NaN         NE
# 28         NaN         NV
# 29         NaN         NH
# 30         NaN         NJ
# 31         NaN         NM
# 32         NaN         NY
# 33         NaN         NC
# 34         NaN         ND
# 35         NaN         OH
# 36         NaN         OK
# 37         NaN         OR
# 38         NaN         PA
# 39         NaN         RI
# 40         NaN         SC
# 41         NaN         SD
# 42         NaN         TN
# 43         NaN         TX
# 44         NaN         UT
# 45         NaN         VT
# 46         NaN         VA
# 47         NaN         WA
# 48         NaN         WV
# 49         NaN         WI
# 50         NaN         WY

# %%
df_state.to_csv('location_state.csv')
# which could generate a csv file in the current file path

# %%
# location_generator(query = df_state.loc[3,'state_code']).json()['historicData']

# %%
data_state = {}
# create a dict to save the data of every state
for row in range(df_state.shape[0]):
    if df_state.loc[row,'state_code'] != 'DC':
    # 'DC' is not a state of US now because of some political problems... just drop the data of DC state
        r = location_generator(query = df_state.loc[row,'state_code'])
        result = r.json()['historicData']
        data_state[df_state.loc[row,'Province_State']] = result

        # data_state save relevant data of every state

# %%
print(len(data_state))
# 50 states of US(except DC state), we are successful!
print(data_state)
# Out:
# 50
# {'Alabama': [{'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 921175, 'deathCt': 16496, 'date': '2022-01-04'}, {'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 932250, 'deathCt': 16503, 'date': '2022-01-05'}, {'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 944876, 'deathCt': 16543, 'date': '2022-01-06'}, {'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 957848, 'deathCt': 16585, 'date': '2022-01-07'}, {'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 966180, 'deathCt': 16624, 'date': '2022-01-08'}, {'provinceStateName': 'Alabama', 'peoplePositiveCasesCt': 978632, 'deathCt': 16624, 'date': '2022-01-09'}], 'Alaska': [{'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 160089, 'deathCt': 979, 'date': '2022-01-04'}, {'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 161678, 'deathCt': 979, 'date': '2022-01-05'}, {'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 161678, 'deathCt': 979, 'date': '2022-01-06'}, {'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 165353, 'deathCt': 980, 'date': '2022-01-07'}, {'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 165353, 'deathCt': 980, 'date': '2022-01-08'}, {'provinceStateName': 'Alaska', 'peoplePositiveCasesCt': 165353, 'deathCt': 980, 'date': '2022-01-09'}], 'Arizona': [{'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1411813, 'deathCt': 24509, 'date': '2022-01-04'}, {'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1419562, 'deathCt': 24570, 'date': '2022-01-05'}, {'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1430241, 'deathCt': 24586, 'date': '2022-01-06'}, {'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1445129, 'deathCt': 24616, 'date': '2022-01-07'}, {'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1461633, 'deathCt': 24704, 'date': '2022-01-08'}, {'provinceStateName': 'Arizona', 'peoplePositiveCasesCt': 1461633, 'deathCt': 24704, 'date': '2022-01-09'}], 'Arkansas': [{'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 581134, 'deathCt': 9248, 'date': '2022-01-04'}, {'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 588622, 'deathCt': 9256, 'date': '2022-01-05'}, {'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 596409, 'deathCt': 9278, 'date': '2022-01-06'}, {'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 604843, 'deathCt': 9298, 'date': '2022-01-07'}, {'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 613014, 'deathCt': 9314, 'date': '2022-01-08'}, {'provinceStateName': 'Arkansas', 'peoplePositiveCasesCt': 613014, 'deathCt': 9314, 'date': '2022-01-09'}], 'California': [{'provinceStateName': 'California', 'peoplePositiveCasesCt': 5768815, 'deathCt': 76634, 'date': '2022-01-04'}, {'provinceStateName': 'California', 'peoplePositiveCasesCt': 5808171, 'deathCt': 76760, 'date': '2022-01-05'}, {'provinceStateName': 'California', 'peoplePositiveCasesCt': 5894761, 'deathCt': 76792, 'date': '2022-01-06'}, {'provinceStateName': 'California', 'peoplePositiveCasesCt': 6003152, 'deathCt': 77026, 'date': '2022-01-07'}, {'provinceStateName': 'California', 'peoplePositiveCasesCt': 6037516, 'deathCt': 77043, 'date': '2022-01-08'}, {'provinceStateName': 'California', 'peoplePositiveCasesCt': 6085177, 'deathCt': 77056, 'date': '2022-01-09'}], 'Colorado': [{'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 962777, 'deathCt': 10335, 'date': '2022-01-04'}, {'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 971525, 'deathCt': 10354, 'date': '2022-01-05'}, {'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 979437, 'deathCt': 10402, 'date': '2022-01-06'}, {'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 989409, 'deathCt': 10425, 'date': '2022-01-07'}, {'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 989409, 'deathCt': 10425, 'date': '2022-01-08'}, {'provinceStateName': 'Colorado', 'peoplePositiveCasesCt': 989409, 'deathCt': 10425, 'date': '2022-01-09'}], 'Connecticut': [{'provinceStateName': 'Connecti ...

# %%
data = pd.DataFrame(columns = ['provinceStateName', 'peoplePositiveCasesCt', 'deathCt', 'date'])
# create a blank dataframe in order to save data in the form of dict

# %%
for state in data_state:
    data = pd.concat([data,pd.DataFrame(data_state[state])])
    # Since we can only extract the data of one state once time, so we need to use for-loop function
    # pd.concat function is used to concat different dataframe vertically

# %%
state_data = data.reset_index(drop = True)
state_data
# reset the index of the state, from 0 to 299
# Out:
#     provinceStateName peoplePositiveCasesCt deathCt        date
# 0             Alabama                921175   16496  2022-01-04
# 1             Alabama                932250   16503  2022-01-05
# 2             Alabama                944876   16543  2022-01-06
# 3             Alabama                957848   16585  2022-01-07
# 4             Alabama                966180   16624  2022-01-08
# ..                ...                   ...     ...         ...
# 295           Wyoming                118098    1572  2022-01-05
# 296           Wyoming                119093    1572  2022-01-06
# 297           Wyoming                119857    1572  2022-01-07
# 298           Wyoming                119857    1572  2022-01-08
# 299           Wyoming                119857    1572  2022-01-09
#
# [300 rows x 4 columns]

# %%
state_data.to_csv('data_state.csv')
# save state_data

# %% [markdown]
# ## county

# %%
df_county = df.iloc[1070:,:]
# 1070 lines of this document represents the data of every county and its state_name
df_county
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 1070  84001001   US  USA  840.0   1001.0     Autauga        Alabama
# 1071  84001003   US  USA  840.0   1003.0     Baldwin        Alabama
# 1072  84001005   US  USA  840.0   1005.0     Barbour        Alabama
# 1073  84001007   US  USA  840.0   1007.0        Bibb        Alabama
# 1074  84001009   US  USA  840.0   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 4209  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 4210  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 4211  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 4212  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 4213  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 1070             US  32.539527  -86.644082     Autauga, Alabama, US
# 1071             US  30.727750  -87.722071     Baldwin, Alabama, US
# 1072             US  31.868263  -85.387129     Barbour, Alabama, US
# 1073             US  32.996421  -87.125115        Bibb, Alabama, US
# 1074             US  33.982109  -86.567906      Blount, Alabama, US
# ...             ...        ...         ...                      ...
# 4209             US  41.659439 -108.882788  Sweetwater, Wyoming, US
# 4210             US  43.935225 -110.589080       Teton, Wyoming, US
# 4211             US  41.287818 -110.547578       Uinta, Wyoming, US
# 4212             US  43.904516 -107.680187    Washakie, Wyoming, US
# 4213             US  43.839612 -104.567488      Weston, Wyoming, US
#
#       Population
# 1070     55869.0
# 1071    223234.0
# 1072     24686.0
# 1073     22394.0
# 1074     57826.0
# ...          ...
# 4209     42343.0
# 4210     23464.0
# 4211     20226.0
# 4212      7805.0
# 4213      6927.0
#
# [3144 rows x 12 columns]

# %%
df_county = df_county.reset_index(drop = True)
df_county
# reset_index is easier for subsequent data operations
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA  840.0   1001.0     Autauga        Alabama
# 1     84001003   US  USA  840.0   1003.0     Baldwin        Alabama
# 2     84001005   US  USA  840.0   1005.0     Barbour        Alabama
# 3     84001007   US  USA  840.0   1007.0        Bibb        Alabama
# 4     84001009   US  USA  840.0   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3139  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 3140  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 3141  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 3142  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 3143  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 0                US  32.539527  -86.644082     Autauga, Alabama, US
# 1                US  30.727750  -87.722071     Baldwin, Alabama, US
# 2                US  31.868263  -85.387129     Barbour, Alabama, US
# 3                US  32.996421  -87.125115        Bibb, Alabama, US
# 4                US  33.982109  -86.567906      Blount, Alabama, US
# ...             ...        ...         ...                      ...
# 3139             US  41.659439 -108.882788  Sweetwater, Wyoming, US
# 3140             US  43.935225 -110.589080       Teton, Wyoming, US
# 3141             US  41.287818 -110.547578       Uinta, Wyoming, US
# 3142             US  43.904516 -107.680187    Washakie, Wyoming, US
# 3143             US  43.839612 -104.567488      Weston, Wyoming, US
#
#       Population
# 0        55869.0
# 1       223234.0
# 2        24686.0
# 3        22394.0
# 4        57826.0
# ...          ...
# 3139     42343.0
# 3140     23464.0
# 3141     20226.0
# 3142      7805.0
# 3143      6927.0
#
# [3144 rows x 12 columns]

# %%
df_county.to_csv('location_county.csv')
# save data of county to csv file

# %%
# data_state = {}

# %%
dict_state = {}
# create a new dict in order to build a connection between state_code and state full name

# %%
df_state.head()
# we need to use 2 columns df_state, Province_State and state_code
# Out:
#         UID iso2 iso3  code3     FIPS     Admin2 Province_State  \
# 0  84080001   US  USA  840.0  80001.0  Out of AL        Alabama
# 1  84080002   US  USA  840.0  80002.0  Out of AK         Alaska
# 2  84080004   US  USA  840.0  80004.0  Out of AZ        Arizona
# 3  84080005   US  USA  840.0  80005.0  Out of AR       Arkansas
# 4  84080006   US  USA  840.0  80006.0  Out of CA     California
#
#   Country_Region  Lat  Long_               Combined_Key  Population state_code
# 0             US  NaN    NaN     Out of AL, Alabama, US         NaN         AL
# 1             US  NaN    NaN      Out of AK, Alaska, US         NaN         AK
# 2             US  NaN    NaN     Out of AZ, Arizona, US         NaN         AZ
# 3             US  NaN    NaN    Out of AR, Arkansas, US         NaN         AR
# 4             US  NaN    NaN  Out of CA, California, US         NaN         CA

# %%
for row in range(df_state.shape[0]):
    state_code = df_state.loc[row,'state_code']
    # extract the state_code
    state_name = df_state.loc[row,'Province_State']
    # extract the state full name
    dict_state[state_name] = state_code
    # built the connection between state_code and state full name, we can look up the state_code use the state full name key in dict_state
#     tmp = pd.concat([tmp,pd.DataFrame(df_county[df_county.Province_State == each])])

# %%
dict_state
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
location_url1 = "https://localcoviddata.com/covid19/v1/cases/jhu?state="
location_url2= "&daysInPast=7&county="

def location_generator_county(state="AL",county="Autauga"):
    state = state.replace(" ", "%20")
    county = county.replace(" ", "%20")
    r = requests.get(location_url1 + state + location_url2 + county)
    return r
    # equals to https://localcoviddata.com/covid19/v1/cases/jhu?state=AL&daysInPast=7&county=Autauga, 
    # which will return the covid data in last 7 days of Autauga of Alabama

# %%
result = {}
# save the covid data of different county to dict

# %%
for row in range(df_county.shape[0]):
    # search every line of df_county
    state_name = df_county.loc[row,'Province_State']
    state_code = dict_state[state_name]
    # return the state_code of every line
    county = df_county.loc[row,'Admin2']
    # return the county name
    try:
        r = location_generator_county(state_code,county)
        result[state_name + '-' + county] = r.json()['historicData']
        # the key is named to [state_name + '-' + county], for example: Alabama-Autauga, 
        # because I found that there will be the same county name of different state.
    except:
        pass
    # using try except function here because there's some unknown problems to county name..
    # Maybe will drop 2 lines of data, but we have 3142 lines of data totally.

# %%
result
# Out:
# {'Alabama-Autauga': [{'provinceStateName': 'Alabama',
#    'deathCt': 161,
#    'peoplePositiveCasesCt': 11347,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 161,
#    'peoplePositiveCasesCt': 11478,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 161,
#    'peoplePositiveCasesCt': 11638,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 162,
#    'peoplePositiveCasesCt': 11789,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 162,
#    'peoplePositiveCasesCt': 11856,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 162,
#    'peoplePositiveCasesCt': 11975,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Baldwin': [{'provinceStateName': 'Alabama',
#    'deathCt': 594,
#    'peoplePositiveCasesCt': 40838,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 594,
#    'peoplePositiveCasesCt': 41312,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 598,
#    'peoplePositiveCasesCt': 41855,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 601,
#    'peoplePositiveCasesCt': 42391,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 603,
#    'peoplePositiveCasesCt': 42738,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 603,
#    'peoplePositiveCasesCt': 43285,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Barbour': [{'provinceStateName': 'Alabama',
#    'deathCt': 81,
#    'peoplePositiveCasesCt': 3999,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 81,
#    'peoplePositiveCasesCt': 4036,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4101,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4150,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4180,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4263,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Bibb': [{'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4616,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4680,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4730,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4815,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4857,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 95,
#    'peoplePositiveCasesCt': 4914,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Blount': [{'provinceStateName': 'Alabama',
#    'deathCt': 198,
#    'peoplePositiveCasesCt': 11430,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 198,
#    'peoplePositiveCasesCt': 11497,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 198,
#    'peoplePositiveCasesCt': 11587,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 199,
#    'peoplePositiveCasesCt': 11690,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 202,
#    'peoplePositiveCasesCt': 11749,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 202,
#    'peoplePositiveCasesCt': 11828,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Bullock': [{'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1724,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1752,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1783,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1806,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1831,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1851,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Butler': [{'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3695,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3773,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3838,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3896,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3919,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 102,
#    'peoplePositiveCasesCt': 3985,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Calhoun': [{'provinceStateName': 'Alabama',
#    'deathCt': 532,
#    'peoplePositiveCasesCt': 23801,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 532,
#    'peoplePositiveCasesCt': 24047,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 532,
#    'peoplePositiveCasesCt': 24282,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 533,
#    'peoplePositiveCasesCt': 24507,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 535,
#    'peoplePositiveCasesCt': 24678,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 535,
#    'peoplePositiveCasesCt': 24866,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Chambers': [{'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6402,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6467,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6603,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6689,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6749,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 147,
#    'peoplePositiveCasesCt': 6887,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Cherokee': [{'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3448,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3487,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3511,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3550,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3569,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3629,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Chilton': [{'provinceStateName': 'Alabama',
#    'deathCt': 173,
#    'peoplePositiveCasesCt': 7571,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 173,
#    'peoplePositiveCasesCt': 7626,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 174,
#    'peoplePositiveCasesCt': 7691,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 175,
#    'peoplePositiveCasesCt': 7778,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 175,
#    'peoplePositiveCasesCt': 7855,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 175,
#    'peoplePositiveCasesCt': 7964,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Choctaw': [{'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1045,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1069,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1110,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1138,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1166,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 30,
#    'peoplePositiveCasesCt': 1174,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Clarke': [{'provinceStateName': 'Alabama',
#    'deathCt': 88,
#    'peoplePositiveCasesCt': 5009,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 88,
#    'peoplePositiveCasesCt': 5088,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 89,
#    'peoplePositiveCasesCt': 5139,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 89,
#    'peoplePositiveCasesCt': 5218,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 89,
#    'peoplePositiveCasesCt': 5260,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 89,
#    'peoplePositiveCasesCt': 5302,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Clay': [{'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2723,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2756,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2801,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2834,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 70,
#    'peoplePositiveCasesCt': 2846,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 70,
#    'peoplePositiveCasesCt': 2901,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Cleburne': [{'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2679,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 61,
#    'peoplePositiveCasesCt': 2706,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 61,
#    'peoplePositiveCasesCt': 2720,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 61,
#    'peoplePositiveCasesCt': 2747,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 61,
#    'peoplePositiveCasesCt': 2763,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 61,
#    'peoplePositiveCasesCt': 2772,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Coffee': [{'provinceStateName': 'Alabama',
#    'deathCt': 196,
#    'peoplePositiveCasesCt': 9950,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 196,
#    'peoplePositiveCasesCt': 10056,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 199,
#    'peoplePositiveCasesCt': 10162,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 200,
#    'peoplePositiveCasesCt': 10285,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 201,
#    'peoplePositiveCasesCt': 10344,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 201,
#    'peoplePositiveCasesCt': 10473,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Colbert': [{'provinceStateName': 'Alabama',
#    'deathCt': 215,
#    'peoplePositiveCasesCt': 10111,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 215,
#    'peoplePositiveCasesCt': 10243,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 216,
#    'peoplePositiveCasesCt': 10380,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 217,
#    'peoplePositiveCasesCt': 10546,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 217,
#    'peoplePositiveCasesCt': 10615,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 217,
#    'peoplePositiveCasesCt': 10749,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Conecuh': [{'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2038,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2052,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2115,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2154,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2169,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 2195,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Coosa': [{'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2009,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2039,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2081,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2117,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2135,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 48,
#    'peoplePositiveCasesCt': 2155,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Covington': [{'provinceStateName': 'Alabama',
#    'deathCt': 200,
#    'peoplePositiveCasesCt': 7219,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 200,
#    'peoplePositiveCasesCt': 7265,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 201,
#    'peoplePositiveCasesCt': 7314,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 203,
#    'peoplePositiveCasesCt': 7375,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 203,
#    'peoplePositiveCasesCt': 7401,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 203,
#    'peoplePositiveCasesCt': 7468,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Crenshaw': [{'provinceStateName': 'Alabama',
#    'deathCt': 79,
#    'peoplePositiveCasesCt': 2823,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 79,
#    'peoplePositiveCasesCt': 2878,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 79,
#    'peoplePositiveCasesCt': 2909,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 79,
#    'peoplePositiveCasesCt': 2943,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 80,
#    'peoplePositiveCasesCt': 2967,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 80,
#    'peoplePositiveCasesCt': 2984,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Cullman': [{'provinceStateName': 'Alabama',
#    'deathCt': 311,
#    'peoplePositiveCasesCt': 17302,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 311,
#    'peoplePositiveCasesCt': 17486,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 311,
#    'peoplePositiveCasesCt': 17650,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 313,
#    'peoplePositiveCasesCt': 17832,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 315,
#    'peoplePositiveCasesCt': 17922,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 315,
#    'peoplePositiveCasesCt': 18098,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Dale': [{'provinceStateName': 'Alabama',
#    'deathCt': 195,
#    'peoplePositiveCasesCt': 9547,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 195,
#    'peoplePositiveCasesCt': 9659,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 195,
#    'peoplePositiveCasesCt': 9758,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 197,
#    'peoplePositiveCasesCt': 9873,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 198,
#    'peoplePositiveCasesCt': 9935,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 198,
#    'peoplePositiveCasesCt': 10013,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Dallas': [{'provinceStateName': 'Alabama',
#    'deathCt': 212,
#    'peoplePositiveCasesCt': 5736,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 212,
#    'peoplePositiveCasesCt': 5804,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 212,
#    'peoplePositiveCasesCt': 5928,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 212,
#    'peoplePositiveCasesCt': 6021,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 213,
#    'peoplePositiveCasesCt': 6080,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 213,
#    'peoplePositiveCasesCt': 6186,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-DeKalb': [{'provinceStateName': 'Alabama',
#    'deathCt': 280,
#    'peoplePositiveCasesCt': 13660,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 280,
#    'peoplePositiveCasesCt': 13732,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 280,
#    'peoplePositiveCasesCt': 13860,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 282,
#    'peoplePositiveCasesCt': 13989,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 283,
#    'peoplePositiveCasesCt': 14096,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 283,
#    'peoplePositiveCasesCt': 14219,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Elmore': [{'provinceStateName': 'Alabama',
#    'deathCt': 298,
#    'peoplePositiveCasesCt': 17109,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 298,
#    'peoplePositiveCasesCt': 17258,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 299,
#    'peoplePositiveCasesCt': 17451,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 299,
#    'peoplePositiveCasesCt': 17669,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 301,
#    'peoplePositiveCasesCt': 17796,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 301,
#    'peoplePositiveCasesCt': 17952,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Escambia': [{'provinceStateName': 'Alabama',
#    'deathCt': 148,
#    'peoplePositiveCasesCt': 7507,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 148,
#    'peoplePositiveCasesCt': 7600,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 149,
#    'peoplePositiveCasesCt': 7708,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 150,
#    'peoplePositiveCasesCt': 7800,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 150,
#    'peoplePositiveCasesCt': 7861,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 150,
#    'peoplePositiveCasesCt': 7945,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Etowah': [{'provinceStateName': 'Alabama',
#    'deathCt': 527,
#    'peoplePositiveCasesCt': 21002,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 527,
#    'peoplePositiveCasesCt': 21142,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 528,
#    'peoplePositiveCasesCt': 21360,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 529,
#    'peoplePositiveCasesCt': 21610,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 530,
#    'peoplePositiveCasesCt': 21752,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 530,
#    'peoplePositiveCasesCt': 21938,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Fayette': [{'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3458,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3478,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3497,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3522,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3539,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 86,
#    'peoplePositiveCasesCt': 3555,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Franklin': [{'provinceStateName': 'Alabama',
#    'deathCt': 111,
#    'peoplePositiveCasesCt': 6631,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 111,
#    'peoplePositiveCasesCt': 6694,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 111,
#    'peoplePositiveCasesCt': 6741,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 112,
#    'peoplePositiveCasesCt': 6798,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 113,
#    'peoplePositiveCasesCt': 6828,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 113,
#    'peoplePositiveCasesCt': 6879,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Geneva': [{'provinceStateName': 'Alabama',
#    'deathCt': 137,
#    'peoplePositiveCasesCt': 4787,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 137,
#    'peoplePositiveCasesCt': 4814,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 4851,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 4877,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 4904,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 4924,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Greene': [{'provinceStateName': 'Alabama',
#    'deathCt': 45,
#    'peoplePositiveCasesCt': 1388,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 45,
#    'peoplePositiveCasesCt': 1393,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1409,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 46,
#    'peoplePositiveCasesCt': 1429,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 47,
#    'peoplePositiveCasesCt': 1446,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 47,
#    'peoplePositiveCasesCt': 1456,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Hale': [{'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3408,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3440,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3467,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3514,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3539,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3583,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Henry': [{'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3371,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3398,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3423,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3446,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3462,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 67,
#    'peoplePositiveCasesCt': 3485,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Houston': [{'provinceStateName': 'Alabama',
#    'deathCt': 433,
#    'peoplePositiveCasesCt': 18824,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 433,
#    'peoplePositiveCasesCt': 19000,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 434,
#    'peoplePositiveCasesCt': 19116,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 436,
#    'peoplePositiveCasesCt': 19290,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 437,
#    'peoplePositiveCasesCt': 19435,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 437,
#    'peoplePositiveCasesCt': 19640,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Jackson': [{'provinceStateName': 'Alabama',
#    'deathCt': 201,
#    'peoplePositiveCasesCt': 10763,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 201,
#    'peoplePositiveCasesCt': 10840,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 202,
#    'peoplePositiveCasesCt': 10916,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 202,
#    'peoplePositiveCasesCt': 11010,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 203,
#    'peoplePositiveCasesCt': 11060,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 203,
#    'peoplePositiveCasesCt': 11121,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Jefferson': [{'provinceStateName': 'Alabama',
#    'deathCt': 2029,
#    'peoplePositiveCasesCt': 131549,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 2029,
#    'peoplePositiveCasesCt': 133216,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 2029,
#    'peoplePositiveCasesCt': 135392,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 2030,
#    'peoplePositiveCasesCt': 137434,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 2033,
#    'peoplePositiveCasesCt': 138918,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 2033,
#    'peoplePositiveCasesCt': 141189,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Lamar': [{'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2625,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2634,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2650,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2661,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2674,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 60,
#    'peoplePositiveCasesCt': 2690,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Lauderdale': [{'provinceStateName': 'Alabama',
#    'deathCt': 319,
#    'peoplePositiveCasesCt': 16154,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 319,
#    'peoplePositiveCasesCt': 16396,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 320,
#    'peoplePositiveCasesCt': 16613,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 320,
#    'peoplePositiveCasesCt': 16849,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 320,
#    'peoplePositiveCasesCt': 17002,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 320,
#    'peoplePositiveCasesCt': 17206,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Lawrence': [{'provinceStateName': 'Alabama',
#    'deathCt': 136,
#    'peoplePositiveCasesCt': 5174,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 136,
#    'peoplePositiveCasesCt': 5231,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 136,
#    'peoplePositiveCasesCt': 5295,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 5354,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 5385,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 138,
#    'peoplePositiveCasesCt': 5432,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Lee': [{'provinceStateName': 'Alabama',
#    'deathCt': 269,
#    'peoplePositiveCasesCt': 27892,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 269,
#    'peoplePositiveCasesCt': 28208,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 271,
#    'peoplePositiveCasesCt': 28620,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 271,
#    'peoplePositiveCasesCt': 28971,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 271,
#    'peoplePositiveCasesCt': 29355,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 271,
#    'peoplePositiveCasesCt': 29749,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Limestone': [{'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 17480,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 17676,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 17910,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 18147,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 18240,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 231,
#    'peoplePositiveCasesCt': 18494,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Lowndes': [{'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 1941,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 1975,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 2005,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 2058,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 2079,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 68,
#    'peoplePositiveCasesCt': 2096,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Macon': [{'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2710,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2765,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2819,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2882,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2923,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 69,
#    'peoplePositiveCasesCt': 2972,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Madison': [{'provinceStateName': 'Alabama',
#    'deathCt': 772,
#    'peoplePositiveCasesCt': 59773,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 772,
#    'peoplePositiveCasesCt': 60408,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 773,
#    'peoplePositiveCasesCt': 61432,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 776,
#    'peoplePositiveCasesCt': 62590,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 776,
#    'peoplePositiveCasesCt': 63239,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 776,
#    'peoplePositiveCasesCt': 64094,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Marengo': [{'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3548,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3608,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3632,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3669,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3696,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 93,
#    'peoplePositiveCasesCt': 3730,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Marion': [{'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5613,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5642,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5693,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5764,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5811,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 132,
#    'peoplePositiveCasesCt': 5840,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Marshall': [{'provinceStateName': 'Alabama',
#    'deathCt': 321,
#    'peoplePositiveCasesCt': 19742,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 322,
#    'peoplePositiveCasesCt': 19928,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 324,
#    'peoplePositiveCasesCt': 20135,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 326,
#    'peoplePositiveCasesCt': 20347,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 329,
#    'peoplePositiveCasesCt': 20486,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 329,
#    'peoplePositiveCasesCt': 20625,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Mobile': [{'provinceStateName': 'Alabama',
#    'deathCt': 1394,
#    'peoplePositiveCasesCt': 81451,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 1397,
#    'peoplePositiveCasesCt': 82969,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 1397,
#    'peoplePositiveCasesCt': 84261,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 1397,
#    'peoplePositiveCasesCt': 85564,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 1401,
#    'peoplePositiveCasesCt': 86415,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 1401,
#    'peoplePositiveCasesCt': 87983,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Monroe': [{'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3664,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3733,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3790,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3859,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3895,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 66,
#    'peoplePositiveCasesCt': 3944,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Montgomery': [{'provinceStateName': 'Alabama',
#    'deathCt': 798,
#    'peoplePositiveCasesCt': 39694,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 799,
#    'peoplePositiveCasesCt': 40450,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 800,
#    'peoplePositiveCasesCt': 41275,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 802,
#    'peoplePositiveCasesCt': 42212,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 802,
#    'peoplePositiveCasesCt': 42763,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 802,
#    'peoplePositiveCasesCt': 43360,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Morgan': [{'provinceStateName': 'Alabama',
#    'deathCt': 426,
#    'peoplePositiveCasesCt': 24407,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 426,
#    'peoplePositiveCasesCt': 24623,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 428,
#    'peoplePositiveCasesCt': 24921,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 431,
#    'peoplePositiveCasesCt': 25222,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 431,
#    'peoplePositiveCasesCt': 25437,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 431,
#    'peoplePositiveCasesCt': 25719,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Perry': [{'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1495,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1520,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1550,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1564,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1582,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 41,
#    'peoplePositiveCasesCt': 1627,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Pickens': [{'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3518,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3566,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 3609,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 92,
#    'peoplePositiveCasesCt': 3664,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 92,
#    'peoplePositiveCasesCt': 3709,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 92,
#    'peoplePositiveCasesCt': 3792,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Alabama-Pike': [{'provinceStateName': 'Alabama',
#    'deathCt': 112,
#    'peoplePositiveCasesCt': 5603,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 112,
#    'peoplePositiveCasesCt': 5656,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 112,
#    'peoplePositiveCasesCt': 5729,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Alabama',
#    'deathCt': 112,
#    'peoplePositiveCasesCt': 5767,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
# ...
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 7,
#    'peoplePositiveCasesCt': 354,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 7,
#    'peoplePositiveCasesCt': 354,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Stevens': [{'provinceStateName': 'Kansas',
#    'deathCt': 16,
#    'peoplePositiveCasesCt': 1081,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 16,
#    'peoplePositiveCasesCt': 1105,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 16,
#    'peoplePositiveCasesCt': 1105,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1129,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1129,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1129,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Sumner': [{'provinceStateName': 'Kansas',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 4108,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 4168,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 62,
#    'peoplePositiveCasesCt': 4168,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 63,
#    'peoplePositiveCasesCt': 4256,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 63,
#    'peoplePositiveCasesCt': 4256,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 63,
#    'peoplePositiveCasesCt': 4256,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Thomas': [{'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1861,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1881,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1881,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1897,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1897,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 23,
#    'peoplePositiveCasesCt': 1897,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Trego': [{'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 570,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 584,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 584,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 9,
#    'peoplePositiveCasesCt': 595,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 9,
#    'peoplePositiveCasesCt': 595,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 9,
#    'peoplePositiveCasesCt': 595,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Wabaunsee': [{'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1248,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1269,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1269,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1290,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1290,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 19,
#    'peoplePositiveCasesCt': 1290,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Wallace': [{'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 350,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 354,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 354,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 359,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 359,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 5,
#    'peoplePositiveCasesCt': 359,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Washington': [{'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1033,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1052,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1052,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1067,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1067,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 17,
#    'peoplePositiveCasesCt': 1067,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Wichita': [{'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 354,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 360,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 360,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 363,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 363,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 8,
#    'peoplePositiveCasesCt': 363,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Wilson': [{'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 1936,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 1984,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 1984,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 2036,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 2036,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 35,
#    'peoplePositiveCasesCt': 2036,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Woodson': [{'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 591,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 603,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 603,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 618,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 618,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 10,
#    'peoplePositiveCasesCt': 618,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kansas-Wyandotte': [{'provinceStateName': 'Kansas',
#    'deathCt': 395,
#    'peoplePositiveCasesCt': 33067,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 396,
#    'peoplePositiveCasesCt': 33944,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 396,
#    'peoplePositiveCasesCt': 33944,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 402,
#    'peoplePositiveCasesCt': 35072,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 402,
#    'peoplePositiveCasesCt': 35072,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kansas',
#    'deathCt': 402,
#    'peoplePositiveCasesCt': 35072,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Adair': [{'provinceStateName': 'Kentucky',
#    'deathCt': 90,
#    'peoplePositiveCasesCt': 4015,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 90,
#    'peoplePositiveCasesCt': 4030,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 90,
#    'peoplePositiveCasesCt': 4051,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 4069,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 4069,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 91,
#    'peoplePositiveCasesCt': 4069,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Allen': [{'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4458,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4495,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4531,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4583,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4583,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 83,
#    'peoplePositiveCasesCt': 4583,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Anderson': [{'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4232,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4261,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4296,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4345,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4345,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 57,
#    'peoplePositiveCasesCt': 4345,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Ballard': [{'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 862,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 871,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 877,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 883,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 883,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 26,
#    'peoplePositiveCasesCt': 883,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Barren': [{'provinceStateName': 'Kentucky',
#    'deathCt': 182,
#    'peoplePositiveCasesCt': 9417,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 182,
#    'peoplePositiveCasesCt': 9479,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 182,
#    'peoplePositiveCasesCt': 9532,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 183,
#    'peoplePositiveCasesCt': 9586,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 183,
#    'peoplePositiveCasesCt': 9586,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 183,
#    'peoplePositiveCasesCt': 9586,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Bath': [{'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2040,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2050,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2059,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2065,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2065,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 34,
#    'peoplePositiveCasesCt': 2065,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  'Kentucky-Bell': [{'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6298,
#    'countryShortName': 'US',
#    'date': '2022-01-04'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6329,
#    'countryShortName': 'US',
#    'date': '2022-01-05'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6368,
#    'countryShortName': 'US',
#    'date': '2022-01-06'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6404,
#    'countryShortName': 'US',
#    'date': '2022-01-07'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6404,
#    'countryShortName': 'US',
#    'date': '2022-01-08'},
#   {'provinceStateName': 'Kentucky',
#    'deathCt': 121,
#    'peoplePositiveCasesCt': 6404,
#    'countryShortName': 'US',
#    'date': '2022-01-09'}],
#  ...}

# %%
print(len(result))
# we have saved the data of 3142 counties!
# Out:
# 3142

# %%
county_data = pd.DataFrame(columns = ['provinceStateName', 'deathCt', 'peoplePositiveCasesCt','countryShortName', 'date', 'state-county'])
county_data
# build a blank dataframe in order to concat data of diffrent counties
# Out:
# Empty DataFrame
# Columns: [provinceStateName, deathCt, peoplePositiveCasesCt, countryShortName, date, state-county]
# Index: []

# %%
for county in result:
    tmp_df = pd.DataFrame(result[county])
    tmp_df['state-county'] = county
    county_data = pd.concat([county_data,tmp_df])
    # we saved the data of every county to tmp in the form of dataframe

# %%
county_data = county_data.reset_index(drop = True)
county_data
# Out:
#       provinceStateName deathCt peoplePositiveCasesCt countryShortName  \
# 0               Alabama     161                 11347               US
# 1               Alabama     161                 11478               US
# 2               Alabama     161                 11638               US
# 3               Alabama     162                 11789               US
# 4               Alabama     162                 11856               US
# ...                 ...     ...                   ...              ...
# 18847           Wyoming      16                  1260               US
# 18848           Wyoming      16                  1261               US
# 18849           Wyoming      16                  1263               US
# 18850           Wyoming      16                  1263               US
# 18851           Wyoming      16                  1263               US
#
#              date     state-county
# 0      2022-01-04  Alabama-Autauga
# 1      2022-01-05  Alabama-Autauga
# 2      2022-01-06  Alabama-Autauga
# 3      2022-01-07  Alabama-Autauga
# 4      2022-01-08  Alabama-Autauga
# ...           ...              ...
# 18847  2022-01-05   Wyoming-Weston
# 18848  2022-01-06   Wyoming-Weston
# 18849  2022-01-07   Wyoming-Weston
# 18850  2022-01-08   Wyoming-Weston
# 18851  2022-01-09   Wyoming-Weston
#
# [18852 rows x 6 columns]

# %%
county_data.to_csv('data_county.csv')
# save the data of county

# %% [markdown]
# ## population

# %%
# This API is provided by Data USA and Deloitte and has the endpoint to state populations data:

url = "https://datausa.io/api/data?drilldowns=State&measures=Population"
r = requests.get(url)
result = r.json()
result
# we have downloaded the population of all states from 2013 to 2019
# Out:
# {'data': [{'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4903185,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 731545,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 7278717,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3017804,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 39512223,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5758736,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3565287,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 973764,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 705749,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 21477737,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 10617423,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1415872,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1787065,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 12671821,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6732219,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3155070,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2913314,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4467673,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4648794,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1344212,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6045680,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6892503,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 9986857,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5639632,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2976149,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6137428,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1068778,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1934408,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3080156,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1359711,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 8882190,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2096829,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 19453561,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 10488084,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 762062,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 11689100,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3956971,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4217737,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 12801989,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1059361,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5148714,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 884659,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6829174,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 28995881,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3205958,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 623989,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 8535519,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 7614893,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1792147,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5822434,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 578759,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3193694,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 4887871,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 737438,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 7171646,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3013825,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 39557045,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 5695564,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3572665,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 967171,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 702455,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 21299325,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 10519475,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1420491,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1754208,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 12741080,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 6691878,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3156145,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 2911510,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 4468402,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 4659978,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1338404,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 6042718,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 6902149,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 9995915,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 5611179,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 2986530,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 6126452,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1062305,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1929268,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3034392,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1356458,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 8908520,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 2095428,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 19542209,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 10383620,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 760077,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 11689442,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3943079,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 4190713,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 12807060,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1057315,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 5084127,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 882235,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 6770010,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 28701845,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3161105,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 626299,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 8517685,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 7535591,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 1805832,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 5813568,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 577737,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 3195153,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 4874747,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 739795,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 7016270,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3004279,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 39536653,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 5607154,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3588184,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 961939,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 693972,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 20984400,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 10429379,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1427538,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1716943,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 12802023,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 6666818,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3145711,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 2913123,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 4454189,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 4684333,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1335907,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 6052177,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 6859819,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 9962311,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 5576606,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 2984100,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 6113532,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1050493,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1920076,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 2998039,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1342795,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 9005644,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 2088070,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 19849399,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 10273419,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 755393,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 11658609,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3930864,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 4142776,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 12805537,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1059639,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 5024369,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 869666,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 6715984,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 28304596,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3101833,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 623657,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 8470020,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 7405743,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 1815857,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 5795483,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 579315,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 3337177,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 4863300,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 741894,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6931071,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 2988248,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 39250017,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 5540545,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 3576452,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 952065,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 681170,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 20612439,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 10310371,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1428557,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1683140,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 12801539,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6633053,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 3134693,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 2907289,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 4436974,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 4681666,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1331479,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6016447,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6811779,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 9928300,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 5519952,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 2988726,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6093000,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1042520,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1907116,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 2940058,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1334795,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 8944469,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 2081015,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 19745289,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 10146788,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 757953,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 11614373,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 3923561,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 4093465,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 12784227,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1056426,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 4961119,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 865454,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 6651194,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 27862596,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 3051217,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 624594,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 8411808,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 7288000,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 1831102,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 5778709,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 585501,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 3411307,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 4858979,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 738432,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6828065,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2978204,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 39144818,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 5456574,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 3590886,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 945934,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 672228,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 20271272,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 10214860,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1431603,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1654930,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 12859995,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6619680,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 3123899,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2911641,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 4425092,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 4670724,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1329328,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6006401,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6794422,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 9922576,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 5489594,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2992333,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6083672,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1032949,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1896190,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2890845,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1330608,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 8958013,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2085109,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 19795791,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 10042802,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 756928,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 11613423,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 3911338,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 4028977,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 12802503,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1056298,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 4896146,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 858469,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 6600299,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 27469114,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 2995919,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 626042,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 8382993,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 7170351,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 1844128,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 5771337,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 586107,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 3474182,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 4849377,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 736732,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 6731484,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2966369,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 38802500,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 5355866,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 3596677,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 935614,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 658893,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 19893297,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 10097343,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1419561,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1634464,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 12880580,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 6596855,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 3107126,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2904021,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 4413457,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 4649676,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1330089,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 5976407,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 6745408,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 9909877,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 5457173,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2994079,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 6063589,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1023579,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1881503,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2839099,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1326813,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 8938175,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2085572,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 19746227,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 9943964,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 739482,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 11594163,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 3878051,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 3970239,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 12787209,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1055173,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 4832482,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 853175,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 6549352,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 26956958,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 2942902,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 626562,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 8326289,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 7061530,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 1850326,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 5757564,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 584153,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 3548397,
#    'Slug State': 'puerto-rico'},
#   {'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 4833722,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 735132,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6626624,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2959373,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 38332521,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 5268367,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 3596080,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 925749,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 646449,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 19552860,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 9992167,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1404054,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1612136,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 12882135,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6570902,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 3090416,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2893957,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 4395295,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 4625470,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1328302,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 5928814,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6692824,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 9895622,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 5420380,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2991207,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6044171,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1015165,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1868516,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2790136,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1323459,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 8899339,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2085287,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 19651127,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 9848060,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 723393,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 11570808,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 3850568,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 3930065,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 12773801,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1051511,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 4774839,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 844877,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6495978,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 26448193,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 2900872,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 626630,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 8260405,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 6971406,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 1854304,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 5742713,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 582658,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 3615086,
#    'Slug State': 'puerto-rico'}],
#  'source': [{'measures': ['Population'],
#    'annotations': {'source_name': 'Census Bureau',
#     'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#     'dataset_name': 'ACS 1-year Estimate',
#     'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#     'table_id': 'B01003',
#     'topic': 'Diversity',
#     'subtopic': 'Demographics'},
#    'name': 'acs_yg_total_population_1',
#    'substitutions': []}]}

# %%
# Using pandas directly generate a dataframe
df = pd.DataFrame(result['data'])
df
# Out:
#       ID State          State  ID Year  Year  Population     Slug State
# 0    04000US01        Alabama     2019  2019     4903185        alabama
# 1    04000US02         Alaska     2019  2019      731545         alaska
# 2    04000US04        Arizona     2019  2019     7278717        arizona
# 3    04000US05       Arkansas     2019  2019     3017804       arkansas
# 4    04000US06     California     2019  2019    39512223     california
# ..         ...            ...      ...   ...         ...            ...
# 359  04000US53     Washington     2013  2013     6971406     washington
# 360  04000US54  West Virginia     2013  2013     1854304  west-virginia
# 361  04000US55      Wisconsin     2013  2013     5742713      wisconsin
# 362  04000US56        Wyoming     2013  2013      582658        wyoming
# 363  04000US72    Puerto Rico     2013  2013     3615086    puerto-rico
#
# [364 rows x 6 columns]

# %%
# Only need the latest number of population, which is 2019.
# The population number in Puerto Rico is excluded as it does not relevant to the first API.
# we kept the suitable data, which should be from 2019(latest) and not be the Puerto Rico(not a state)
df_population_2019 = df[(df['Year'] == '2019') & (df['State'] != 'Puerto Rico')]
df_population_2019
# Out:
#      ID State                 State  ID Year  Year  Population  \
# 0   04000US01               Alabama     2019  2019     4903185
# 1   04000US02                Alaska     2019  2019      731545
# 2   04000US04               Arizona     2019  2019     7278717
# 3   04000US05              Arkansas     2019  2019     3017804
# 4   04000US06            California     2019  2019    39512223
# 5   04000US08              Colorado     2019  2019     5758736
# 6   04000US09           Connecticut     2019  2019     3565287
# 7   04000US10              Delaware     2019  2019      973764
# 8   04000US11  District of Columbia     2019  2019      705749
# 9   04000US12               Florida     2019  2019    21477737
# 10  04000US13               Georgia     2019  2019    10617423
# 11  04000US15                Hawaii     2019  2019     1415872
# 12  04000US16                 Idaho     2019  2019     1787065
# 13  04000US17              Illinois     2019  2019    12671821
# 14  04000US18               Indiana     2019  2019     6732219
# 15  04000US19                  Iowa     2019  2019     3155070
# 16  04000US20                Kansas     2019  2019     2913314
# 17  04000US21              Kentucky     2019  2019     4467673
# 18  04000US22             Louisiana     2019  2019     4648794
# 19  04000US23                 Maine     2019  2019     1344212
# 20  04000US24              Maryland     2019  2019     6045680
# 21  04000US25         Massachusetts     2019  2019     6892503
# 22  04000US26              Michigan     2019  2019     9986857
# 23  04000US27             Minnesota     2019  2019     5639632
# 24  04000US28           Mississippi     2019  2019     2976149
# 25  04000US29              Missouri     2019  2019     6137428
# 26  04000US30               Montana     2019  2019     1068778
# 27  04000US31              Nebraska     2019  2019     1934408
# 28  04000US32                Nevada     2019  2019     3080156
# 29  04000US33         New Hampshire     2019  2019     1359711
# 30  04000US34            New Jersey     2019  2019     8882190
# 31  04000US35            New Mexico     2019  2019     2096829
# 32  04000US36              New York     2019  2019    19453561
# 33  04000US37        North Carolina     2019  2019    10488084
# 34  04000US38          North Dakota     2019  2019      762062
# 35  04000US39                  Ohio     2019  2019    11689100
# 36  04000US40              Oklahoma     2019  2019     3956971
# 37  04000US41                Oregon     2019  2019     4217737
# 38  04000US42          Pennsylvania     2019  2019    12801989
# 39  04000US44          Rhode Island     2019  2019     1059361
# 40  04000US45        South Carolina     2019  2019     5148714
# 41  04000US46          South Dakota     2019  2019      884659
# 42  04000US47             Tennessee     2019  2019     6829174
# 43  04000US48                 Texas     2019  2019    28995881
# 44  04000US49                  Utah     2019  2019     3205958
# 45  04000US50               Vermont     2019  2019      623989
# 46  04000US51              Virginia     2019  2019     8535519
# 47  04000US53            Washington     2019  2019     7614893
# 48  04000US54         West Virginia     2019  2019     1792147
# 49  04000US55             Wisconsin     2019  2019     5822434
# 50  04000US56               Wyoming     2019  2019      578759
#
#               Slug State
# 0                alabama
# 1                 alaska
# 2                arizona
# 3               arkansas
# 4             california
# 5               colorado
# 6            connecticut
# 7               delaware
# 8   district-of-columbia
# 9                florida
# 10               georgia
# 11                hawaii
# 12                 idaho
# 13              illinois
# 14               indiana
# 15                  iowa
# 16                kansas
# 17              kentucky
# 18             louisiana
# 19                 maine
# 20              maryland
# 21         massachusetts
# 22              michigan
# 23             minnesota
# 24           mississippi
# 25              missouri
# 26               montana
# 27              nebraska
# 28                nevada
# 29         new-hampshire
# 30            new-jersey
# 31            new-mexico
# 32              new-york
# 33        north-carolina
# 34          north-dakota
# 35                  ohio
# 36              oklahoma
# 37                oregon
# 38          pennsylvania
# 39          rhode-island
# 40        south-carolina
# 41          south-dakota
# 42             tennessee
# 43                 texas
# 44                  utah
# 45               vermont
# 46              virginia
# 47            washington
# 48         west-virginia
# 49             wisconsin
# 50               wyoming

# %%
# If needed, using the line below to export the data as a CSV document to a specified path
# It is '/Users/adorex/Downloads/University of Warwick/e-BM/Big Data Technology & Visualisation/IMA/state_populations.csv' for example
# df.to_csv(path_or_buf = '/Users/adorex/Downloads/University of Warwick/e-BM/Big Data Technology & Visualisation/IMA/state_populations.csv')

# %% [markdown]
# # To Mongodb part

# %% [markdown]
# We have generated 5 csv files and 5 different dataframe:
# * df_state: the data of every state and state_code
# * state_data: the covid data of every state in last 7 days
# * df_county: the data of every county and every state(Longitude and latitude are important to use in data visualisation part)
# * county_data: the covid data of every county in last 7 days
# * df_population_2019: the population data of every state in 2019(latest)

# %%
df_state
# Out:
#          UID iso2 iso3  code3     FIPS     Admin2        Province_State  \
# 0   84080001   US  USA  840.0  80001.0  Out of AL               Alabama
# 1   84080002   US  USA  840.0  80002.0  Out of AK                Alaska
# 2   84080004   US  USA  840.0  80004.0  Out of AZ               Arizona
# 3   84080005   US  USA  840.0  80005.0  Out of AR              Arkansas
# 4   84080006   US  USA  840.0  80006.0  Out of CA            California
# 5   84080008   US  USA  840.0  80008.0  Out of CO              Colorado
# 6   84080009   US  USA  840.0  80009.0  Out of CT           Connecticut
# 7   84080010   US  USA  840.0  80010.0  Out of DE              Delaware
# 8   84080011   US  USA  840.0  80011.0  Out of DC  District of Columbia
# 9   84080012   US  USA  840.0  80012.0  Out of FL               Florida
# 10  84080013   US  USA  840.0  80013.0  Out of GA               Georgia
# 11  84080015   US  USA  840.0  80015.0  Out of HI                Hawaii
# 12  84080016   US  USA  840.0  80016.0  Out of ID                 Idaho
# 13  84080017   US  USA  840.0  80017.0  Out of IL              Illinois
# 14  84080018   US  USA  840.0  80018.0  Out of IN               Indiana
# 15  84080019   US  USA  840.0  80019.0  Out of IA                  Iowa
# 16  84080020   US  USA  840.0  80020.0  Out of KS                Kansas
# 17  84080021   US  USA  840.0  80021.0  Out of KY              Kentucky
# 18  84080022   US  USA  840.0  80022.0  Out of LA             Louisiana
# 19  84080023   US  USA  840.0  80023.0  Out of ME                 Maine
# 20  84080024   US  USA  840.0  80024.0  Out of MD              Maryland
# 21  84080025   US  USA  840.0  80025.0  Out of MA         Massachusetts
# 22  84080026   US  USA  840.0  80026.0  Out of MI              Michigan
# 23  84080027   US  USA  840.0  80027.0  Out of MN             Minnesota
# 24  84080028   US  USA  840.0  80028.0  Out of MS           Mississippi
# 25  84080029   US  USA  840.0  80029.0  Out of MO              Missouri
# 26  84080030   US  USA  840.0  80030.0  Out of MT               Montana
# 27  84080031   US  USA  840.0  80031.0  Out of NE              Nebraska
# 28  84080032   US  USA  840.0  80032.0  Out of NV                Nevada
# 29  84080033   US  USA  840.0  80033.0  Out of NH         New Hampshire
# 30  84080034   US  USA  840.0  80034.0  Out of NJ            New Jersey
# 31  84080035   US  USA  840.0  80035.0  Out of NM            New Mexico
# 32  84080036   US  USA  840.0  80036.0  Out of NY              New York
# 33  84080037   US  USA  840.0  80037.0  Out of NC        North Carolina
# 34  84080038   US  USA  840.0  80038.0  Out of ND          North Dakota
# 35  84080039   US  USA  840.0  80039.0  Out of OH                  Ohio
# 36  84080040   US  USA  840.0  80040.0  Out of OK              Oklahoma
# 37  84080041   US  USA  840.0  80041.0  Out of OR                Oregon
# 38  84080042   US  USA  840.0  80042.0  Out of PA          Pennsylvania
# 39  84080044   US  USA  840.0  80044.0  Out of RI          Rhode Island
# 40  84080045   US  USA  840.0  80045.0  Out of SC        South Carolina
# 41  84080046   US  USA  840.0  80046.0  Out of SD          South Dakota
# 42  84080047   US  USA  840.0  80047.0  Out of TN             Tennessee
# 43  84080048   US  USA  840.0  80048.0  Out of TX                 Texas
# 44  84080049   US  USA  840.0  80049.0  Out of UT                  Utah
# 45  84080050   US  USA  840.0  80050.0  Out of VT               Vermont
# 46  84080051   US  USA  840.0  80051.0  Out of VA              Virginia
# 47  84080053   US  USA  840.0  80053.0  Out of WA            Washington
# 48  84080054   US  USA  840.0  80054.0  Out of WV         West Virginia
# 49  84080055   US  USA  840.0  80055.0  Out of WI             Wisconsin
# 50  84080056   US  USA  840.0  80056.0  Out of WY               Wyoming
#
#    Country_Region  Lat  Long_                         Combined_Key  \
# 0              US  NaN    NaN               Out of AL, Alabama, US
# 1              US  NaN    NaN                Out of AK, Alaska, US
# 2              US  NaN    NaN               Out of AZ, Arizona, US
# 3              US  NaN    NaN              Out of AR, Arkansas, US
# 4              US  NaN    NaN            Out of CA, California, US
# 5              US  NaN    NaN              Out of CO, Colorado, US
# 6              US  NaN    NaN           Out of CT, Connecticut, US
# 7              US  NaN    NaN              Out of DE, Delaware, US
# 8              US  NaN    NaN  Out of DC, District of Columbia, US
# 9              US  NaN    NaN               Out of FL, Florida, US
# 10             US  NaN    NaN               Out of GA, Georgia, US
# 11             US  NaN    NaN                Out of HI, Hawaii, US
# 12             US  NaN    NaN                 Out of ID, Idaho, US
# 13             US  NaN    NaN              Out of IL, Illinois, US
# 14             US  NaN    NaN               Out of IN, Indiana, US
# 15             US  NaN    NaN                  Out of IA, Iowa, US
# 16             US  NaN    NaN                Out of KS, Kansas, US
# 17             US  NaN    NaN              Out of KY, Kentucky, US
# 18             US  NaN    NaN             Out of LA, Louisiana, US
# 19             US  NaN    NaN                 Out of ME, Maine, US
# 20             US  NaN    NaN              Out of MD, Maryland, US
# 21             US  NaN    NaN         Out of MA, Massachusetts, US
# 22             US  NaN    NaN              Out of MI, Michigan, US
# 23             US  NaN    NaN             Out of MN, Minnesota, US
# 24             US  NaN    NaN           Out of MS, Mississippi, US
# 25             US  NaN    NaN              Out of MO, Missouri, US
# 26             US  NaN    NaN               Out of MT, Montana, US
# 27             US  NaN    NaN              Out of NE, Nebraska, US
# 28             US  NaN    NaN                Out of NV, Nevada, US
# 29             US  NaN    NaN         Out of NH, New Hampshire, US
# 30             US  NaN    NaN            Out of NJ, New Jersey, US
# 31             US  NaN    NaN            Out of NM, New Mexico, US
# 32             US  NaN    NaN              Out of NY, New York, US
# 33             US  NaN    NaN        Out of NC, North Carolina, US
# 34             US  NaN    NaN          Out of ND, North Dakota, US
# 35             US  NaN    NaN                  Out of OH, Ohio, US
# 36             US  NaN    NaN              Out of OK, Oklahoma, US
# 37             US  NaN    NaN                Out of OR, Oregon, US
# 38             US  NaN    NaN          Out of PA, Pennsylvania, US
# 39             US  NaN    NaN          Out of RI, Rhode Island, US
# 40             US  NaN    NaN        Out of SC, South Carolina, US
# 41             US  NaN    NaN          Out of SD, South Dakota, US
# 42             US  NaN    NaN             Out of TN, Tennessee, US
# 43             US  NaN    NaN                 Out of TX, Texas, US
# 44             US  NaN    NaN                  Out of UT, Utah, US
# 45             US  NaN    NaN               Out of VT, Vermont, US
# 46             US  NaN    NaN              Out of VA, Virginia, US
# 47             US  NaN    NaN            Out of WA, Washington, US
# 48             US  NaN    NaN         Out of WV, West Virginia, US
# 49             US  NaN    NaN             Out of WI, Wisconsin, US
# 50             US  NaN    NaN               Out of WY, Wyoming, US
#
#     Population state_code
# 0          NaN         AL
# 1          NaN         AK
# 2          NaN         AZ
# 3          NaN         AR
# 4          NaN         CA
# 5          NaN         CO
# 6          NaN         CT
# 7          NaN         DE
# 8          NaN         DC
# 9          NaN         FL
# 10         NaN         GA
# 11         NaN         HI
# 12         NaN         ID
# 13         NaN         IL
# 14         NaN         IN
# 15         NaN         IA
# 16         NaN         KS
# 17         NaN         KY
# 18         NaN         LA
# 19         NaN         ME
# 20         NaN         MD
# 21         NaN         MA
# 22         NaN         MI
# 23         NaN         MN
# 24         NaN         MS
# 25         NaN         MO
# 26         NaN         MT
# 27         NaN         NE
# 28         NaN         NV
# 29         NaN         NH
# 30         NaN         NJ
# 31         NaN         NM
# 32         NaN         NY
# 33         NaN         NC
# 34         NaN         ND
# 35         NaN         OH
# 36         NaN         OK
# 37         NaN         OR
# 38         NaN         PA
# 39         NaN         RI
# 40         NaN         SC
# 41         NaN         SD
# 42         NaN         TN
# 43         NaN         TX
# 44         NaN         UT
# 45         NaN         VT
# 46         NaN         VA
# 47         NaN         WA
# 48         NaN         WV
# 49         NaN         WI
# 50         NaN         WY

# %%
state_data
# Out:
#     provinceStateName peoplePositiveCasesCt deathCt        date
# 0             Alabama                921175   16496  2022-01-04
# 1             Alabama                932250   16503  2022-01-05
# 2             Alabama                944876   16543  2022-01-06
# 3             Alabama                957848   16585  2022-01-07
# 4             Alabama                966180   16624  2022-01-08
# ..                ...                   ...     ...         ...
# 295           Wyoming                118098    1572  2022-01-05
# 296           Wyoming                119093    1572  2022-01-06
# 297           Wyoming                119857    1572  2022-01-07
# 298           Wyoming                119857    1572  2022-01-08
# 299           Wyoming                119857    1572  2022-01-09
#
# [300 rows x 4 columns]

# %%
df_county
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA  840.0   1001.0     Autauga        Alabama
# 1     84001003   US  USA  840.0   1003.0     Baldwin        Alabama
# 2     84001005   US  USA  840.0   1005.0     Barbour        Alabama
# 3     84001007   US  USA  840.0   1007.0        Bibb        Alabama
# 4     84001009   US  USA  840.0   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3139  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 3140  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 3141  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 3142  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 3143  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 0                US  32.539527  -86.644082     Autauga, Alabama, US
# 1                US  30.727750  -87.722071     Baldwin, Alabama, US
# 2                US  31.868263  -85.387129     Barbour, Alabama, US
# 3                US  32.996421  -87.125115        Bibb, Alabama, US
# 4                US  33.982109  -86.567906      Blount, Alabama, US
# ...             ...        ...         ...                      ...
# 3139             US  41.659439 -108.882788  Sweetwater, Wyoming, US
# 3140             US  43.935225 -110.589080       Teton, Wyoming, US
# 3141             US  41.287818 -110.547578       Uinta, Wyoming, US
# 3142             US  43.904516 -107.680187    Washakie, Wyoming, US
# 3143             US  43.839612 -104.567488      Weston, Wyoming, US
#
#       Population
# 0        55869.0
# 1       223234.0
# 2        24686.0
# 3        22394.0
# 4        57826.0
# ...          ...
# 3139     42343.0
# 3140     23464.0
# 3141     20226.0
# 3142      7805.0
# 3143      6927.0
#
# [3144 rows x 12 columns]

# %%
county_data
# Out:
#       provinceStateName deathCt peoplePositiveCasesCt countryShortName  \
# 0               Alabama     161                 11347               US
# 1               Alabama     161                 11478               US
# 2               Alabama     161                 11638               US
# 3               Alabama     162                 11789               US
# 4               Alabama     162                 11856               US
# ...                 ...     ...                   ...              ...
# 18847           Wyoming      16                  1260               US
# 18848           Wyoming      16                  1261               US
# 18849           Wyoming      16                  1263               US
# 18850           Wyoming      16                  1263               US
# 18851           Wyoming      16                  1263               US
#
#              date     state-county
# 0      2022-01-04  Alabama-Autauga
# 1      2022-01-05  Alabama-Autauga
# 2      2022-01-06  Alabama-Autauga
# 3      2022-01-07  Alabama-Autauga
# 4      2022-01-08  Alabama-Autauga
# ...           ...              ...
# 18847  2022-01-05   Wyoming-Weston
# 18848  2022-01-06   Wyoming-Weston
# 18849  2022-01-07   Wyoming-Weston
# 18850  2022-01-08   Wyoming-Weston
# 18851  2022-01-09   Wyoming-Weston
#
# [18852 rows x 6 columns]

# %%
df_population_2019
# Out:
#      ID State                 State  ID Year  Year  Population  \
# 0   04000US01               Alabama     2019  2019     4903185
# 1   04000US02                Alaska     2019  2019      731545
# 2   04000US04               Arizona     2019  2019     7278717
# 3   04000US05              Arkansas     2019  2019     3017804
# 4   04000US06            California     2019  2019    39512223
# 5   04000US08              Colorado     2019  2019     5758736
# 6   04000US09           Connecticut     2019  2019     3565287
# 7   04000US10              Delaware     2019  2019      973764
# 8   04000US11  District of Columbia     2019  2019      705749
# 9   04000US12               Florida     2019  2019    21477737
# 10  04000US13               Georgia     2019  2019    10617423
# 11  04000US15                Hawaii     2019  2019     1415872
# 12  04000US16                 Idaho     2019  2019     1787065
# 13  04000US17              Illinois     2019  2019    12671821
# 14  04000US18               Indiana     2019  2019     6732219
# 15  04000US19                  Iowa     2019  2019     3155070
# 16  04000US20                Kansas     2019  2019     2913314
# 17  04000US21              Kentucky     2019  2019     4467673
# 18  04000US22             Louisiana     2019  2019     4648794
# 19  04000US23                 Maine     2019  2019     1344212
# 20  04000US24              Maryland     2019  2019     6045680
# 21  04000US25         Massachusetts     2019  2019     6892503
# 22  04000US26              Michigan     2019  2019     9986857
# 23  04000US27             Minnesota     2019  2019     5639632
# 24  04000US28           Mississippi     2019  2019     2976149
# 25  04000US29              Missouri     2019  2019     6137428
# 26  04000US30               Montana     2019  2019     1068778
# 27  04000US31              Nebraska     2019  2019     1934408
# 28  04000US32                Nevada     2019  2019     3080156
# 29  04000US33         New Hampshire     2019  2019     1359711
# 30  04000US34            New Jersey     2019  2019     8882190
# 31  04000US35            New Mexico     2019  2019     2096829
# 32  04000US36              New York     2019  2019    19453561
# 33  04000US37        North Carolina     2019  2019    10488084
# 34  04000US38          North Dakota     2019  2019      762062
# 35  04000US39                  Ohio     2019  2019    11689100
# 36  04000US40              Oklahoma     2019  2019     3956971
# 37  04000US41                Oregon     2019  2019     4217737
# 38  04000US42          Pennsylvania     2019  2019    12801989
# 39  04000US44          Rhode Island     2019  2019     1059361
# 40  04000US45        South Carolina     2019  2019     5148714
# 41  04000US46          South Dakota     2019  2019      884659
# 42  04000US47             Tennessee     2019  2019     6829174
# 43  04000US48                 Texas     2019  2019    28995881
# 44  04000US49                  Utah     2019  2019     3205958
# 45  04000US50               Vermont     2019  2019      623989
# 46  04000US51              Virginia     2019  2019     8535519
# 47  04000US53            Washington     2019  2019     7614893
# 48  04000US54         West Virginia     2019  2019     1792147
# 49  04000US55             Wisconsin     2019  2019     5822434
# 50  04000US56               Wyoming     2019  2019      578759
#
#               Slug State
# 0                alabama
# 1                 alaska
# 2                arizona
# 3               arkansas
# 4             california
# 5               colorado
# 6            connecticut
# 7               delaware
# 8   district-of-columbia
# 9                florida
# 10               georgia
# 11                hawaii
# 12                 idaho
# 13              illinois
# 14               indiana
# 15                  iowa
# 16                kansas
# 17              kentucky
# 18             louisiana
# 19                 maine
# 20              maryland
# 21         massachusetts
# 22              michigan
# 23             minnesota
# 24           mississippi
# 25              missouri
# 26               montana
# 27              nebraska
# 28                nevada
# 29         new-hampshire
# 30            new-jersey
# 31            new-mexico
# 32              new-york
# 33        north-carolina
# 34          north-dakota
# 35                  ohio
# 36              oklahoma
# 37                oregon
# 38          pennsylvania
# 39          rhode-island
# 40        south-carolina
# 41          south-dakota
# 42             tennessee
# 43                 texas
# 44                  utah
# 45               vermont
# 46              virginia
# 47            washington
# 48         west-virginia
# 49             wisconsin
# 50               wyoming
